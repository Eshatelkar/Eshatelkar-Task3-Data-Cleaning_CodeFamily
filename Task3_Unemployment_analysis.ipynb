# %% [markdown]
# <a href="https://colab.research.google.com/github/Eshatelkar/Eshatelkar-Task3-Data-Cleaning_CodeFamily/blob/main/Task3_Unemployment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path='/content/drive/MyDrive/unemployment analysis.csv'
df=pd.read_csv(path)

# %%
df
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %% [markdown]
# # **Data Cleaning**

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
# Removing unwanted columns and keeping the rows as it is 
columns_to_remove = ['1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012']

print('Before removing unwanted columns: {}'.format(df.shape))
df.drop(labels=columns_to_remove, axis=1, inplace=True)
print('After removing unwanted columns: {}'.format(df.shape))
# Out:
# Before removing unwanted columns: (235, 33)
# After removing unwanted columns: (235, 12)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1991', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df
# Out:
#                     Country Name Country Code   1991   2013   2014   2015  \
# 0    Africa Eastern and Southern          AFE   7.80   6.45   6.41   6.49
# 1                    Afghanistan          AFG  10.65  11.19  11.14  11.13
# 2     Africa Western and Central          AFW   4.42   4.41   4.69   4.63
# 3                         Angola          AGO   4.21   7.37   7.37   7.39
# 4                        Albania          ALB  10.31  15.87  18.05  17.19
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   8.67   8.72   8.50
# 231                  Yemen, Rep.          YEM   8.32  13.27  13.47  13.77
# 232                 South Africa          ZAF  29.95  24.56  24.89  25.15
# 233                       Zambia          ZMB  18.90   8.61   9.36  10.13
# 234                     Zimbabwe          ZWE   4.94   4.98   4.77   4.78
#
#       2016   2017   2018   2019   2020   2021
# ...

# %%
df['1991'].unique()
# Out:
# array([ 7.8 , 10.65,  4.42,  4.21, 10.31, 11.62,  1.87,  5.44,  1.6 ,
#         9.58,  3.42,  0.9 ,  1.51,  6.99,  1.49,  2.58,  2.2 , 11.1 ,
#         1.01, 12.17, 17.55,  0.6 ,  9.7 ,  2.96,  6.31, 22.67,  4.7 ,
#         1.41, 13.82,  5.62, 10.32,  9.25,  1.78,  5.96,  5.23,  2.37,
#         6.61,  7.5 ,  2.93, 20.07, 10.12,  5.11, 11.27,  5.37, 16.05,
#         7.9 ,  3.  ,  2.27,  5.32, 29.36,  9.1 ,  6.35, 20.6 ,  2.4 ,
#         5.36,  2.45,  4.99,  6.91,  4.37,  9.38,  8.25, 15.93,  1.47,
#         3.08,  8.5 ,  4.58,  6.5 ,  4.06,  9.13, 17.78,  8.55,  2.7 ,
#         3.49,  4.45,  8.83,  6.19,  8.13,  7.66,  2.59,  3.51, 11.93,
#         6.75,  1.8 ,  4.88, 11.14,  7.51,  4.55,  4.41,  3.67,  3.06,
#         2.62,  3.93,  5.6 , 15.78,  2.55, 13.39, 10.1 , 15.74, 19.51,
#         2.1 ,  3.12,  1.  ,  0.73,  2.41,  0.88,  5.84,  2.53,  8.37,
#         2.23, 19.85, 16.91,  6.12,  3.85,  4.75, 14.66,  4.26, 36.12,
# ...

# %%
# Removing the first 5  data in the year 1991
print('Before removing first 5  data: {}'.format(df.shape))
df = df[df['1991']>=5.0]
print('After removing first 5  data: {}'.format(df.shape))
# Out:
# Before removing first 5  data: (235, 12)
# After removing first 5  data: (129, 12)

# %%
df
# Out:
#                     Country Name Country Code   1991   2013   2014   2015  \
# 0    Africa Eastern and Southern          AFE   7.80   6.45   6.41   6.49
# 1                    Afghanistan          AFG  10.65  11.19  11.14  11.13
# 4                        Albania          ALB  10.31  15.87  18.05  17.19
# 5                     Arab World          ARB  11.62  10.74  10.87  10.97
# 7                      Argentina          ARG   5.44   7.10   7.27   7.52
# ..                           ...          ...    ...    ...    ...    ...
# 225                Venezuela, RB          VEN   9.45   7.54   6.86   6.08
# 226        Virgin Islands (U.S.)          VIR  12.35  12.76  12.79  12.62
# 231                  Yemen, Rep.          YEM   8.32  13.27  13.47  13.77
# 232                 South Africa          ZAF  29.95  24.56  24.89  25.15
# 233                       Zambia          ZMB  18.90   8.61   9.36  10.13
#
#       2016   2017   2018   2019   2020   2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  129 non-null    object
#  1   Country Code  129 non-null    object
#  2   1991          129 non-null    float64
#  3   2013          129 non-null    float64
#  4   2014          129 non-null    float64
#  5   2015          129 non-null    float64
#  6   2016          129 non-null    float64
#  7   2017          129 non-null    float64
#  8   2018          129 non-null    float64
#  9   2019          129 non-null    float64
#  10  2020          129 non-null    float64
#  11  2021          129 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 13.1+ KB

# %%
df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1991            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
df['1991'].hist(bins=10)
plt.xlabel('Country')
plt.ylabel('value')
plt.title('Distribution')
plt.show();

# %%
df['2015'].hist(bins=5)
plt.xlabel('Country')
plt.ylabel('value')
plt.title('Distribution')
plt.show();

# %%
df['2017'].hist(bins=8)
plt.xlabel('Country')
plt.ylabel('value')
plt.title('Distribution')
plt.show();
